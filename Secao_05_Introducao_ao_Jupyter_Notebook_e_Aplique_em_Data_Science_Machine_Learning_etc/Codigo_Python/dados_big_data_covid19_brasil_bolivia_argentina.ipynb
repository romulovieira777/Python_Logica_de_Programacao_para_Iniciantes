# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("vaccinations.csv")

# %%
data
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0    Argentina      ARG  2020-12-29               700.0                NaN
# 1    Argentina      ARG  2020-12-30                 NaN                NaN
# 2    Argentina      ARG  2020-12-31             32013.0                NaN
# 3    Argentina      ARG  2021-01-01                 NaN                NaN
# 4    Argentina      ARG  2021-01-02                 NaN                NaN
# ..         ...      ...         ...                 ...                ...
# 669     Brazil      BRA  2021-08-22         176616552.0        126453502.0
# 670     Brazil      BRA  2021-08-23         178551085.0        127635209.0
# 671     Brazil      BRA  2021-08-24         179727882.0        128359705.0
# 672     Brazil      BRA  2021-08-25         181908368.0        129675516.0
# 673     Brazil      BRA  2021-08-26         186279872.0        132202507.0
#
# ...

# %%
data.columns
# Out:
# Index(['location', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'daily_vaccinations_per_million'],
#       dtype='object')

# %%
sns.relplot(x="total_vaccinations", y="daily_vaccinations", data=data)

# %%
sns.relplot(x="location", y="daily_vaccinations", data=data)

# %%
sns.relplot(x="location", y="people_fully_vaccinated", data=data)

# %%
sns.relplot(x="location", y="daily_vaccinations_per_million", data=data)

# %%
sns.relplot(x="date", y="daily_vaccinations_raw", data=data)
